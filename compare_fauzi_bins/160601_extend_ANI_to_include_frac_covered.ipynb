# %%
import glob
import sys

# %%
import pandas as pd

# %%
#sys.path.append('')

# %%
import aggregate_mummer_results

# %%
test_samples = glob.glob('./mummer_results/*.tsv')

# %%
single_result = aggregate_mummer_results.prepare_result(test_samples[0])

# %%
single_result
# Out:
#        TAGS (ref)    TAGS (query)  LEN 1  LEN 2  LEN R  LEN Q  COV R  COV Q  \
# 0  Ga0081624_1057  Ga0081631_1040     78     78   4137   4450   1.89   1.75
# 1  Ga0081624_1202  Ga0081631_1098    211    208   7025   2727   3.00   7.63
#
#     % IDY                                        mummer file  \
# 0  100.00  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
# 1   82.08  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
#
#                   ...                                query bin name  \
# 0                 ...                   Rhodocyclaceae-49_Ga0081631
# 1                 ...                   Rhodocyclaceae-49_Ga0081631
#
#               ref name ref contig count                   ref bin name  \
# 0  Methylophilaceae-40              240  Methylophilaceae-40_Ga0081624
# 1  Methylophilaceae-40              240  Methylophilaceae-40_Ga0081624
#
#   query bp  query contigs                    query file name   ref bp  \
# ...

# %%
aggregate_mummer_results.length_weighted_percent_identity(single_result)
# Out:
# 86.967272727272729

# %%
single_result
# Out:
#        TAGS (ref)    TAGS (query)  LEN 1  LEN 2  LEN R  LEN Q  COV R  COV Q  \
# 0  Ga0081624_1057  Ga0081631_1040     78     78   4137   4450   1.89   1.75
# 1  Ga0081624_1202  Ga0081631_1098    211    208   7025   2727   3.00   7.63
#
#     % IDY                                        mummer file  \
# 0  100.00  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
# 1   82.08  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
#
#                   ...                                query bin name  \
# 0                 ...                   Rhodocyclaceae-49_Ga0081631
# 1                 ...                   Rhodocyclaceae-49_Ga0081631
#
#               ref name ref contig count                   ref bin name  \
# 0  Methylophilaceae-40              240  Methylophilaceae-40_Ga0081624
# 1  Methylophilaceae-40              240  Methylophilaceae-40_Ga0081624
#
#   query bp  query contigs                    query file name   ref bp  \
# ...

# %%
len(single_result['ref bin'].unique())
# Out:
# 1

# %%
# First load the datframe from the file path, and load on meta info. 
aggregate_mummer_results.prepare_result(test_samples[2])
# Out:
#       TAGS (ref)    TAGS (query)  LEN 1  LEN 2   LEN R  LEN Q  COV R  COV Q  \
# 0  Ga0081609_106  Ga0081643_1097    500    500  415700  15446   0.12   3.24
# 1  Ga0081609_107  Ga0081643_1041    384    384  133018  23283   0.29   1.65
# 2  Ga0081609_112  Ga0081643_1027    501    504  106346  36342   0.47   1.39
#
#    % IDY                                        mummer file  \
# 0  82.07  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
# 1  86.27  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
# 2  80.79  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
#
#                 ...                                   query bin name  \
# 0               ...                Methylosarcina_lacus-69_Ga0081643
# 1               ...                Methylosarcina_lacus-69_Ga0081643
# 2               ...                Methylosarcina_lacus-69_Ga0081643
#
#          ref name ref contig count              ref bin name query bp  \
# ...

# %%
mixed_control = pd.concat([aggregate_mummer_results.prepare_result(test_samples[0]),
                          aggregate_mummer_results.prepare_result(test_samples[2])])

# %%
mixed_control
# Out:
#        TAGS (ref)    TAGS (query)  LEN 1  LEN 2   LEN R  LEN Q  COV R  COV Q  \
# 0  Ga0081624_1057  Ga0081631_1040     78     78    4137   4450   1.89   1.75
# 1  Ga0081624_1202  Ga0081631_1098    211    208    7025   2727   3.00   7.63
# 0   Ga0081609_106  Ga0081643_1097    500    500  415700  15446   0.12   3.24
# 1   Ga0081609_107  Ga0081643_1041    384    384  133018  23283   0.29   1.65
# 2   Ga0081609_112  Ga0081643_1027    501    504  106346  36342   0.47   1.39
#
#     % IDY                                        mummer file  \
# 0  100.00  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
# 1   82.08  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...
# 0   82.07  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
# 1   86.27  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
# 2   80.79  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...
#
#                   ...                                      query bin name  \
# ...

# %%
# should return False. 
aggregate_mummer_results.dataframe_is_one_query_target_pair(mixed_control)
# Out:
# False

# %%
aggregate_mummer_results.summarize(test_samples[0])
# Out:
#                                          mummer file    ref bin  query bin  \
# 0  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...  Ga0081624  Ga0081631
#
#           query name  query contig count               query bin name  \
# 0  Rhodocyclaceae-49                 190  Rhodocyclaceae-49_Ga0081631
#
#               ref name  ref contig count                   ref bin name  \
# 0  Methylophilaceae-40               240  Methylophilaceae-40_Ga0081624
#
#    query bp  query contigs                    query file name   ref bp  \
# 0   3699670            189  Rhodocyclaceae-49_Ga0081631.fasta  1297884
#
#    ref contigs                        ref file name  % identity  \
# 0          239  Methylophilaceae-40_Ga0081624.fasta   86.967273
#
#    query alignment length total  number alignments aggregated
# 0                           286                             2

# %%
x = aggregate_mummer_results.percent_idty_all_results(test_samples)
# Out:
# --> ./mummer_results/Rhodocyclaceae-49_Ga0081631_to_Methylophilaceae-40_Ga0081624.tsv:
# no rows for ./mummer_results/Bacteroidetes-8_Ga0081654_to_Opitutae-129_Ga0081615.tsv; assume zero similarity
# --> ./mummer_results/Methylosarcina_lacus-69_Ga0081643_to_Acidovorax-123_Ga0081609.tsv:
# --> ./mummer_results/Methylosarcina_lacus-55_Ga0081634_to_Acidovorax-79_Ga0081651.tsv:
# no rows for ./mummer_results/Methylosarcina-21_Ga0081622_to_Bacteriovorax-49_Ga0081630.tsv; assume zero similarity
# --> ./mummer_results/Methylotenera_mobilis-76-1_Ga0081647_to_Methylotenera_mobilis-63_Ga0081640.tsv:
# --> ./mummer_results/Methylobacter-69_Ga0081641_to_Acidovorax-127_Ga0081613.tsv:
# --> ./mummer_results/Methylophilus_methylotrophus-127-1_Ga0081611_to_Acidovorax-21_Ga0081621.tsv:
# no rows for ./mummer_results/Methylosarcina_lacus-69_Ga0081643_to_Methylophilus_methylotrophus-79_Ga0081650.tsv; assume zero similarity
# ...

# %%
x.head()
# Out:
#                                          mummer file    ref bin  query bin  \
# 0  Rhodocyclaceae-49_Ga0081631_to_Methylophilacea...  Ga0081624  Ga0081631
# 0  Methylosarcina_lacus-69_Ga0081643_to_Acidovora...  Ga0081609  Ga0081643
# 0  Methylosarcina_lacus-55_Ga0081634_to_Acidovora...  Ga0081651  Ga0081634
# 0  Methylotenera_mobilis-76-1_Ga0081647_to_Methyl...  Ga0081640  Ga0081647
# 0  Methylobacter-69_Ga0081641_to_Acidovorax-127_G...  Ga0081613  Ga0081641
#
#                    query name  query contig count  \
# 0           Rhodocyclaceae-49                 190
# 0     Methylosarcina lacus-69                 217
# 0     Methylosarcina lacus-55                 443
# 0  Methylotenera mobilis-76-1                 208
# 0            Methylobacter-69                 180
#
#                          query bin name                  ref name  \
# 0           Rhodocyclaceae-49_Ga0081631       Methylophilaceae-40
# 0     Methylosarcina_lacus-69_Ga0081643            Acidovorax-123
# ...
