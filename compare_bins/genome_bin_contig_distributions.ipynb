# %%
import pandas as pd

# %%
import re

# %%
import contig_distributions as cd

# %%
df = cd.prepare_summary_df()

# %%
del df['row name']

# %%
df.head()
# Out:
#         contig ID contig number        bin               name
# 0  Ga0081607_1001          1001  Ga0081607  Methylobacter-123
# 1  Ga0081607_1002          1002  Ga0081607  Methylobacter-123
# 2  Ga0081607_1003          1003  Ga0081607  Methylobacter-123
# 3  Ga0081607_1004          1004  Ga0081607  Methylobacter-123
# 4  Ga0081607_1005          1005  Ga0081607  Methylobacter-123

# %%
df.name.unique()
# Out:
# array(['Methylobacter-123', 'Methylotenera mobilis-123', 'Acidovorax-123',
#        'Rhodocyclaceae-127', 'Methylophilus methylotrophus-127-1',
#        'Methylophilus methylotrophus-127-2', 'Acidovorax-127',
#        'Methylobacter tundripaludum-129', 'Opitutae-129',
#        'Burkholderiales-129', 'Methylophilus methylotrophus-129-1',
#        'Methylophilus methylotrophus-129-2', 'Bacteriovorax-21',
#        'Bacteria-21', 'Acidovorax-21', 'Methylosarcina-21',
#        'Methylococcaceae-21', 'Methylophilaceae-40', 'Opititae-40',
#        'Methylophilaceae-49', 'Methylotenera mobilis-49',
#        'Bacteroidetes-49', 'Bacteriovorax-49', 'Rhodocyclaceae-49',
#        'Flavobacteriaceae-49', 'Methylophilus methylotrophus-55',
#        'Methylosarcina lacus-55', 'Burkholderiales-55',
#        'Methylococcaceae-55', 'Methylophilaceae-55',
#        'Methylovulum miyakonense-55', 'Bacteriovorax-63',
#        'Methylotenera mobilis-63', 'Methylobacter-69',
# ...

# %%
summary = cd.summarise_df(df).sort_values('name')
summary
# Out:
#           bin                                name  contig count  \
# 37  Ga0081644                       Acidovora-69x           445
# 2   Ga0081609                      Acidovorax-123            18
# 6   Ga0081613                      Acidovorax-127            60
# 14  Ga0081621                       Acidovorax-21           446
# 38  Ga0081645                       Acidovorax-75           268
# 44  Ga0081651                       Acidovorax-79            98
# 51  Ga0081659                       Acidovorax-98           359
# 13  Ga0081620                         Bacteria-21           254
# 48  Ga0081656                     Bacteriovora-8x           290
# 12  Ga0081619                    Bacteriovorax-21            52
# 23  Ga0081630                    Bacteriovorax-49           377
# 32  Ga0081639                    Bacteriovorax-63             9
# 21  Ga0081628                    Bacteroidetes-49            70
# 39  Ga0081646                    Bacteroidetes-76           251
# ...
