# %%
import sys

# %%
import re

# %%
import glob
import pandas as pd

# %%
sys.path.append('./support_files/')

# %%
import aggregate_mummer_results as amr
import name_extractions

# %%
import plotting

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

% matplotlib inline

# %%
import seaborn as sns
sns.set_style('ticks')

# %%
summary_df = pd.read_csv("./percent_identities.tsv", sep='\t')

# %%
name_extractions.summary_stat_type('estimated % identity (2)')
# Out:
# 'estimated % identity'

# %%
summary_df.head()
# Out:
#    Unnamed: 0  % identity (1)  % identity (2)  estimated % identity (1)  \
# 0           0       89.512390       89.512390                  1.101441
# 1           0       90.094688       90.087233                  9.281476
# 2           0       91.209037       91.226886                  3.687345
# 3           0      100.000000      100.000000                  0.005769
# 4           0       93.064607       92.872315                  5.462180
#
#    estimated % identity (2)  frac of query aligned (1)  \
# 0                  1.101441                   0.012305
# 1                 10.257853                   0.103019
# 2                  3.793253                   0.040427
# 3                  0.005769                   0.000058
# 4                  5.595582                   0.058692
#
#    frac of query aligned (2)  \
# 0                   0.012305
# 1                   0.113866
# 2                   0.041580
# 3                   0.000058
# 4                   0.060250
#
#                                          mummer file  \
# 0  elviz-contigs-1056229.Burkholderiales-1/elviz-...
# 1  elviz-contigs-1056229.Burkholderiales-1/elviz-...
# 2  elviz-contigs-1056229.Burkholderiales-1/elviz-...
# 3  elviz-contigs-1056229.Burkholderiales-1/elviz-...
# 4  elviz-contigs-1056229.Burkholderiales-1/elviz-...
#
#    number alignments aggregated (1)  number alignments aggregated (2)  \
# 0                                94                                94
# 1                               799                               918
# 2                               280                               293
# 3                                 1                                 1
# 4                               270                               282
#
#    query alignment length total (1)  query alignment length total (2)  \
# 0                             33702                             33702
# 1                            282160                            311868
# 2                            110727                            113885
# 3                               158                               158
# 4                            160753                            165020
#
#    query bp  query contigs   query id  \
# 0   2738909           4662  Ga0066473
# 1   2738909           4662  Ga0066473
# 2   2738909           4662  Ga0066473
# 3   2738909           4662  Ga0066473
# 4   2738909           4662  Ga0066473
#
#                                 query name   ref bp  ref contigs     ref id  \
# 0  elviz-contigs-1056229.Burkholderiales-1  2022224         1990  Ga0066401
# 1  elviz-contigs-1056229.Burkholderiales-1  4860710         5582  Ga0066479
# 2  elviz-contigs-1056229.Burkholderiales-1  2881263         2858  Ga0066437
# 3  elviz-contigs-1056229.Burkholderiales-1  2904105          102  Ga0066438
# 4  elviz-contigs-1056229.Burkholderiales-1  3012106          445  Ga0081644
#
#                                   ref name
# 0   elviz-contigs-1056013.Comamonadaceae-1
# 1  elviz-contigs-1056247.Burkholderiales-1
# 2   elviz-contigs-1056121.Comamonadaceae-2
# 3    elviz-contigs-1056124.Methylophilus-1
# 4                            Acidovorax-69

# %%
column_pairs = [
    ('% identity (1)', '% identity (2)'),
    ('frac of query aligned (1)', 'frac of query aligned (2)'),
    ('estimated % identity (1)', 'estimated % identity (2)')
               ]

# %%
plotting.plot_old_versus_new_ani(summary_df, column_pairs)
# Out:
# 0
# ('% identity (1)', '% identity (2)')
# Axes(0.125,0.125;0.227941x0.775)
# 1
# ('frac of query aligned (1)', 'frac of query aligned (2)')
# Axes(0.398529,0.125;0.227941x0.775)
# 2
# ('estimated % identity (1)', 'estimated % identity (2)')
# Axes(0.672059,0.125;0.227941x0.775)
